# %%
from x86_manual_lines import X86_TEST_INPUTS
from bincfg.normalization.norm_utils import *

X86_TEST_INPUTS
# Out:
# [{'input': None,
#   'bad_assembly': False,
#   'x86_base_tokenizer': [('inst_addr', '0x00402cc8:'),
#    ('spacing', ' '),
#    ('opcode', 'sub'),
#    ('spacing', '    '),
#    ('register', 'rsp'),
#    ('spacing', ', '),
#    ('immediate', '0x08'),
#    ('newline', '\n')],
#   'x86_base': [None],
#   'x86_innereye': [None],
#   'x86_deepbindiff': [None],
#   'x86_safe': [None],
#   'x86_deepsemantic': [None],
#   'x86_hpc': [None],
#   'x86_hpc_repl': [None]},
#  {'input': None,
#   'bad_assembly': False,
#   'x86_base_tokenizer': [('inst_addr', '0x00402ccc:'),
#    ('spacing', ' '),
#    ('opcode', 'mov'),
#    ('spacing', '    '),
#    ('register', 'rax'),
#    ('spacing', ', '),
#    ('memory_size', 'qword'),
#    ('spacing', ' '),
#    ('register', 'ds'),
#    ('colon', ':'),
#    ('open_bracket', '['),
#    ('register', 'rip'),
#    ('spacing', ' '),
#    ('plus_sign', '+'),
#    ('spacing', ' '),
#    ('immediate', '0x000000000025230d'),
# ...
